# %% [markdown]
# <a href="https://colab.research.google.com/github/3lLobo/basic-probability-programming/blob/master/naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O files.zip https://github.com/probabll/basic-probability-programming/raw/master/weekly_tasks/week4/homework/files_for_development.zip
# !unzip files.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: files_for_development/20news-18828/sci.electronics/54043
#   inflating: files_for_development/20news-18828/sci.electronics/53880
#   inflating: files_for_development/20news-18828/sci.electronics/54245
#   inflating: files_for_development/20news-18828/sci.electronics/52794
#   inflating: files_for_development/20news-18828/sci.electronics/54041
#   inflating: files_for_development/20news-18828/sci.electronics/53833
#   inflating: files_for_development/20news-18828/sci.electronics/53847
#   inflating: files_for_development/20news-18828/sci.electronics/54344
#   inflating: files_for_development/20news-18828/sci.electronics/53948
#   inflating: files_for_development/20news-18828/sci.electronics/53814
#   inflating: files_for_development/20news-18828/sci.electronics/54303
#   inflating: files_for_development/20news-18828/sci.electronics/54045
#   inflating: files_for_development/20news-18828/sci.electronics/54207
#   inflating: files_for_development/20news-18828/sci.electronics/52798
#   inflating: files_for_development/20news-18828/sci.electronics/54186
#   inflating: files_for_development/20news-18828/sci.electronics/53960
#   inflating: files_for_development/20news-18828/sci.electronics/52776
#   inflating: files_for_development/20news-18828/sci.electronics/54012
#   inflating: files_for_development/20news-18828/sci.electronics/54153
#   inflating: files_for_development/20news-18828/sci.electronics/54282
#   inflating: files_for_development/20news-18828/sci.electronics/53639
#   inflating: files_for_development/20news-18828/sci.electronics/53922
#   inflating: files_for_development/20news-18828/sci.electronics/54161
#   inflating: files_for_development/20news-18828/sci.electronics/52464
#   inflating: files_for_development/20news-18828/sci.electronics/53741
#   inflating: files_for_development/20news-18828/sci.electronics/53600
#   inflating: files_for_development/20news-18828/sci.electronics/53765
#   inflating: files_for_development/20news-18828/sci.electronics/53749
#   inflating: files_for_development/20news-18828/sci.electronics/53984
#   inflating: files_for_development/20news-18828/sci.electronics/53857
#   inflating: files_for_development/20news-18828/sci.electronics/54028
#   inflating: files_for_development/20news-18828/sci.electronics/54295
#   inflating: files_for_development/20news-18828/sci.electronics/53505
#   inflating: files_for_development/20news-18828/sci.electronics/54325
#   inflating: files_for_development/20news-18828/sci.electronics/54269
#   inflating: files_for_development/20news-18828/sci.electronics/54263
#   inflating: files_for_development/20news-18828/sci.electronics/52761
#   inflating: files_for_development/20news-18828/sci.electronics/53785
#   inflating: files_for_development/20news-18828/sci.electronics/54228
#   inflating: files_for_development/20news-18828/sci.electronics/54074
#   inflating: files_for_development/20news-18828/sci.electronics/54162
#   inflating: files_for_development/20news-18828/sci.electronics/52737
#   inflating: files_for_development/20news-18828/sci.electronics/53776
#   inflating: files_for_development/20news-18828/sci.electronics/52723
#   inflating: files_for_development/20news-18828/sci.electronics/54063
#   inflating: files_for_development/20news-18828/sci.electronics/53128
#   inflating: files_for_development/20news-18828/sci.electronics/53805
#   inflating: files_for_development/20news-18828/sci.electronics/53819
#   inflating: files_for_development/20news-18828/sci.electronics/54122
#   inflating: files_for_development/20news-18828/sci.electronics/54181
#   inflating: files_for_development/20news-18828/sci.electronics/54483
#   inflating: files_for_development/20news-18828/sci.electronics/53624
#   inflating: files_for_development/20news-18828/sci.electronics/53967
#   inflating: files_for_development/20news-18828/sci.electronics/53840
#   inflating: files_for_development/20news-18828/sci.electronics/52746
#   inflating: files_for_development/20news-18828/sci.electronics/53645
#   inflating: files_for_development/20news-18828/sci.electronics/53809
#   inflating: files_for_development/20news-18828/sci.electronics/54038
#   inflating: files_for_development/20news-18828/sci.electronics/53955
#   inflating: files_for_development/20news-18828/sci.electronics/53873
#   inflating: files_for_development/20news-18828/sci.electronics/54154
#   inflating: files_for_development/20news-18828/sci.electronics/53625
#   inflating: files_for_development/20news-18828/sci.electronics/53680
#   inflating: files_for_development/20news-18828/sci.electronics/54481
#   inflating: files_for_development/20news-18828/sci.electronics/52740
#   inflating: files_for_development/20news-18828/sci.electronics/54302
#   inflating: files_for_development/20news-18828/sci.electronics/53558
#   inflating: files_for_development/20news-18828/sci.electronics/54318
#   inflating: files_for_development/20news-18828/sci.electronics/54064
#   inflating: files_for_development/20news-18828/sci.electronics/53689
#   inflating: files_for_development/20news-18828/sci.electronics/54250
#   inflating: files_for_development/20news-18828/sci.electronics/54156
#   inflating: files_for_development/20news-18828/sci.electronics/53859
#   inflating: files_for_development/20news-18828/sci.electronics/53616
#   inflating: files_for_development/20news-18828/sci.electronics/54057
#   inflating: files_for_development/20news-18828/sci.electronics/54082
#   inflating: files_for_development/20news-18828/sci.electronics/53519
#   inflating: files_for_development/20news-18828/sci.electronics/53817
#   inflating: files_for_development/20news-18828/sci.electronics/54069
#   inflating: files_for_development/20news-18828/sci.electronics/53687
#   inflating: files_for_development/20news-18828/sci.electronics/53897
#   inflating: files_for_development/20news-18828/sci.electronics/53757
#   inflating: files_for_development/20news-18828/sci.electronics/53604
#   inflating: files_for_development/20news-18828/sci.electronics/53569
#   inflating: files_for_development/20news-18828/sci.electronics/53870
#   inflating: files_for_development/20news-18828/sci.electronics/53586
#   inflating: files_for_development/20news-18828/sci.electronics/53739
#   inflating: files_for_development/20news-18828/sci.electronics/54487
#   inflating: files_for_development/20news-18828/sci.electronics/53548
#   inflating: files_for_development/20news-18828/sci.electronics/54490
#   inflating: files_for_development/20news-18828/sci.electronics/52777
#   inflating: files_for_development/20news-18828/sci.electronics/54111
#   inflating: files_for_development/20news-18828/sci.electronics/53612
#   inflating: files_for_development/20news-18828/sci.electronics/53784
#   inflating: files_for_development/20news-18828/sci.electronics/54334
#   inflating: files_for_development/20news-18828/sci.electronics/54479
#   inflating: files_for_development/20news-18828/sci.electronics/54048
#   inflating: files_for_development/20news-18828/sci.electronics/54140
#   inflating: files_for_development/20news-18828/sci.electronics/53562
#   inflating: files_for_development/20news-18828/sci.electronics/53853
#   inflating: files_for_development/20news-18828/sci.electronics/54198
#   inflating: files_for_development/20news-18828/sci.electronics/53538
#   inflating: files_for_development/20news-18828/sci.electronics/53810
#   inflating: files_for_development/20news-18828/sci.electronics/54274
#   inflating: files_for_development/20news-18828/sci.electronics/53511
#   inflating: files_for_development/20news-18828/sci.electronics/54190
#   inflating: files_for_development/20news-18828/sci.electronics/53767
#   inflating: files_for_development/20news-18828/sci.electronics/52830
#   inflating: files_for_development/20news-18828/sci.electronics/54039
#   inflating: files_for_development/20news-18828/sci.electronics/54342
#   inflating: files_for_development/20news-18828/sci.electronics/54030
#   inflating: files_for_development/20news-18828/sci.electronics/54118
#   inflating: files_for_development/20news-18828/sci.electronics/53640
#   inflating: files_for_development/20news-18828/sci.electronics/54316
#   inflating: files_for_development/20news-18828/sci.electronics/53919
#   inflating: files_for_development/20news-18828/sci.electronics/54241
#   inflating: files_for_development/20news-18828/sci.electronics/54240
#   inflating: files_for_development/20news-18828/sci.electronics/54096
#   inflating: files_for_development/20news-18828/sci.electronics/54215
#   inflating: files_for_development/20news-18828/sci.electronics/53904
#   inflating: files_for_development/20news-18828/sci.electronics/53529
#   inflating: files_for_development/20news-18828/sci.electronics/54253
#   inflating: files_for_development/20news-18828/sci.electronics/53843
#   inflating: files_for_development/20news-18828/sci.electronics/53633
#   inflating: files_for_development/20news-18828/sci.electronics/54289
#   inflating: files_for_development/20news-18828/sci.electronics/53620
#   inflating: files_for_development/20news-18828/sci.electronics/54120
#   inflating: files_for_development/20news-18828/sci.electronics/53631
#   inflating: files_for_development/20news-18828/sci.electronics/53966
#   inflating: files_for_development/20news-18828/sci.electronics/53670
#   inflating: files_for_development/20news-18828/sci.electronics/53534
#   inflating: files_for_development/20news-18828/sci.electronics/53610
#   inflating: files_for_development/20news-18828/sci.electronics/54094
#   inflating: files_for_development/20news-18828/sci.electronics/53575
#   inflating: files_for_development/20news-18828/sci.electronics/52750
#   inflating: files_for_development/20news-18828/sci.electronics/52786
#   inflating: files_for_development/20news-18828/sci.electronics/54291
#   inflating: files_for_development/20news-18828/sci.electronics/54009
#   inflating: files_for_development/20news-18828/sci.electronics/54168
#   inflating: files_for_development/20news-18828/sci.electronics/52805
#   inflating: files_for_development/20news-18828/sci.electronics/53642
#   inflating: files_for_development/20news-18828/sci.electronics/54499
#   inflating: files_for_development/20news-18828/sci.electronics/53711
#   inflating: files_for_development/20news-18828/sci.electronics/52781
#   inflating: files_for_development/20news-18828/sci.electronics/53772
#   inflating: files_for_development/20news-18828/sci.electronics/53978
#   inflating: files_for_development/20news-18828/sci.electronics/53638
#   inflating: files_for_development/20news-18828/sci.electronics/53990
#   inflating: files_for_development/20news-18828/sci.electronics/54088
#   inflating: files_for_development/20news-18828/sci.electronics/53661
#   inflating: files_for_development/20news-18828/sci.electronics/53996
#   inflating: files_for_development/20news-18828/sci.electronics/53608
#   inflating: files_for_development/20news-18828/sci.electronics/52783
#   inflating: files_for_development/20news-18828/sci.electronics/53989
#   inflating: files_for_development/20news-18828/sci.electronics/54151
#   inflating: files_for_development/20news-18828/sci.electronics/53934
#   inflating: files_for_development/20news-18828/sci.electronics/53937
#   inflating: files_for_development/20news-18828/sci.electronics/53726
#   inflating: files_for_development/20news-18828/sci.electronics/53770
#   inflating: files_for_development/20news-18828/sci.electronics/53733
#   inflating: files_for_development/20news-18828/sci.electronics/53818
#   inflating: files_for_development/20news-18828/sci.electronics/54129
#   inflating: files_for_development/20news-18828/sci.electronics/54066
#   inflating: files_for_development/20news-18828/sci.electronics/53544
#   inflating: files_for_development/20news-18828/sci.electronics/53766
#    creating: files_for_development/20news-18828/sci.med/
#   inflating: files_for_development/20news-18828/sci.med/58841
#   inflating: files_for_development/20news-18828/sci.med/58847
#   inflating: files_for_development/20news-18828/sci.med/58850
#   inflating: files_for_development/20news-18828/sci.med/58853
#   inflating: files_for_development/20news-18828/sci.med/58855
#   inflating: files_for_development/20news-18828/sci.med/58860
#   inflating: files_for_development/20news-18828/sci.med/58866
#   inflating: files_for_development/20news-18828/sci.med/58871
#   inflating: files_for_development/20news-18828/sci.med/58928
#   inflating: files_for_development/20news-18828/sci.med/58879
#   inflating: files_for_development/20news-18828/sci.med/59027
#   inflating: files_for_development/20news-18828/sci.med/58880
#   inflating: files_for_development/20news-18828/sci.med/59294
#   inflating: files_for_development/20news-18828/sci.med/59470
#   inflating: files_for_development/20news-18828/sci.med/57110
#   inflating: files_for_development/20news-18828/sci.med/58786
#   inflating: files_for_development/20news-18828/sci.med/58793
#   inflating: files_for_development/20news-18828/sci.med/58773
#   inflating: files_for_development/20news-18828/sci.med/59092
#   inflating: files_for_development/20news-18828/sci.med/58966
#   inflating: files_for_development/20news-18828/sci.med/59078
#   inflating: files_for_development/20news-18828/sci.med/59001
#   inflating: files_for_development/20news-18828/sci.med/59059
#   inflating: files_for_development/20news-18828/sci.med/59641
#   inflating: files_for_development/20news-18828/sci.med/59336
#   inflating: files_for_development/20news-18828/sci.med/59467
#   inflating: files_for_development/20news-18828/sci.med/59289
#   inflating: files_for_development/20news-18828/sci.med/59481
#   inflating: files_for_development/20news-18828/sci.med/59492
#   inflating: files_for_development/20news-18828/sci.med/58947
#   inflating: files_for_development/20news-18828/sci.med/59073
#   inflating: files_for_development/20news-18828/sci.med/59161
#   inflating: files_for_development/20news-18828/sci.med/59282
#   inflating: files_for_development/20news-18828/sci.med/58998
#   inflating: files_for_development/20news-18828/sci.med/59076
#   inflating: files_for_development/20news-18828/sci.med/58822
#   inflating: files_for_development/20news-18828/sci.med/59466
#   inflating: files_for_development/20news-18828/sci.med/59145
#   inflating: files_for_development/20news-18828/sci.med/59633
#   inflating: files_for_development/20news-18828/sci.med/58794
#   inflating: files_for_development/20news-18828/sci.med/59220
#   inflating: files_for_development/20news-18828/sci.med/59395
#   inflating: files_for_development/20news-18828/sci.med/59038
#   inflating: files_for_development/20news-18828/sci.med/59062
#   inflating: files_for_development/20news-18828/sci.med/59543
#   inflating: files_for_development/20news-18828/sci.med/58834
#   inflating: files_for_development/20news-18828/sci.med/58900
#   inflating: files_for_development/20news-18828/sci.med/58886
#   inflating: files_for_development/20news-18828/sci.med/58802
#   inflating: files_for_development/20news-18828/sci.med/59437
#   inflating: files_for_development/20news-18828/sci.med/59559
#   inflating: files_for_development/20news-18828/sci.med/58977
#   inflating: files_for_development/20news-18828/sci.med/59520
#   inflating: files_for_development/20news-18828/sci.med/59563
#   inflating: files_for_development/20news-18828/sci.med/58882
#   inflating: files_for_development/20news-18828/sci.med/58121
#   inflating: files_for_development/20news-18828/sci.med/59208
#   inflating: files_for_development/20news-18828/sci.med/59271
#   inflating: files_for_development/20news-18828/sci.med/59254
#   inflating: files_for_development/20news-18828/sci.med/59602
#   inflating: files_for_development/20news-18828/sci.med/59404
#   inflating: files_for_development/20news-18828/sci.med/59120
#   inflating: files_for_development/20news-18828/sci.med/59238
#   inflating: files_for_development/20news-18828/sci.med/59136
#   inflating: files_for_development/20news-18828/sci.med/59353
#   inflating: files_for_development/20news-18828/sci.med/59507
#   inflating: files_for_development/20news-18828/sci.med/59054
#   inflating: files_for_development/20news-18828/sci.med/59262
#   inflating: files_for_development/20news-18828/sci.med/58939
#   inflating: files_for_development/20news-18828/sci.med/59046
#   inflating: files_for_development/20news-18828/sci.med/58877
#   inflating: files_for_development/20news-18828/sci.med/59486
#   inflating: files_for_development/20news-18828/sci.med/59117
#   inflating: files_for_development/20news-18828/sci.med/59496
#   inflating: files_for_development/20news-18828/sci.med/59182
#   inflating: files_for_development/20news-18828/sci.med/59556
#   inflating: files_for_development/20news-18828/sci.med/59210
#   inflating: files_for_development/20news-18828/sci.med/58095
#   inflating: files_for_development/20news-18828/sci.med/59493
#   inflating: files_for_development/20news-18828/sci.med/59566
#   inflating: files_for_development/20news-18828/sci.med/58828
#   inflating: files_for_development/20news-18828/sci.med/58876
#   inflating: files_for_development/20news-18828/sci.med/58143
#   inflating: files_for_development/20news-18828/sci.med/59620
#   inflating: files_for_development/20news-18828/sci.med/59485
#   inflating: files_for_development/20news-18828/sci.med/59552
#   inflating: files_for_development/20news-18828/sci.med/58152
#   inflating: files_for_development/20news-18828/sci.med/59518
#   inflating: files_for_development/20news-18828/sci.med/58105
#   inflating: files_for_development/20news-18828/sci.med/59333
#   inflating: files_for_development/20news-18828/sci.med/58769
#   inflating: files_for_development/20news-18828/sci.med/59068
#   inflating: files_for_development/20news-18828/sci.med/59155
#   inflating: files_for_development/20news-18828/sci.med/59450
#   inflating: files_for_development/20news-18828/sci.med/59192
#   inflating: files_for_development/20news-18828/sci.med/59365
#   inflating: files_for_development/20news-18828/sci.med/59246
#   inflating: files_for_development/20news-18828/sci.med/58859
#   inflating: files_for_development/20news-18828/sci.med/58072
#   inflating: files_for_development/20news-18828/sci.med/58897
#   inflating: files_for_development/20news-18828/sci.med/58136
#   inflating: files_for_development/20news-18828/sci.med/58986
#   inflating: files_for_development/20news-18828/sci.med/59265
#   inflating: files_for_development/20news-18828/sci.med/58848
#   inflating: files_for_development/20news-18828/sci.med/58996
#   inflating: files_for_development/20news-18828/sci.med/58835
#   inflating: files_for_development/20news-18828/sci.med/59584
#   inflating: files_for_development/20news-18828/sci.med/59526
#   inflating: files_for_development/20news-18828/sci.med/59121
#   inflating: files_for_development/20news-18828/sci.med/58578
#   inflating: files_for_development/20news-18828/sci.med/59323
#   inflating: files_for_development/20news-18828/sci.med/59615
#   inflating: files_for_development/20news-18828/sci.med/58137
#   inflating: files_for_development/20news-18828/sci.med/58135
#   inflating: files_for_development/20news-18828/sci.med/59002
#   inflating: files_for_development/20news-18828/sci.med/59570
#   inflating: files_for_development/20news-18828/sci.med/58844
#   inflating: files_for_development/20news-18828/sci.med/59224
#   inflating: files_for_development/20news-18828/sci.med/59367
#   inflating: files_for_development/20news-18828/sci.med/59358
#   inflating: files_for_development/20news-18828/sci.med/59619
#   inflating: files_for_development/20news-18828/sci.med/59089
#   inflating: files_for_development/20news-18828/sci.med/58792
#   inflating: files_for_development/20news-18828/sci.med/59498
#   inflating: files_for_development/20news-18828/sci.med/59299
#   inflating: files_for_development/20news-18828/sci.med/58893
#   inflating: files_for_development/20news-18828/sci.med/58142
#   inflating: files_for_development/20news-18828/sci.med/58826
#   inflating: files_for_development/20news-18828/sci.med/58111
#   inflating: files_for_development/20news-18828/sci.med/59318
#   inflating: files_for_development/20news-18828/sci.med/58884
#   inflating: files_for_development/20news-18828/sci.med/58873
#   inflating: files_for_development/20news-18828/sci.med/58965
#   inflating: files_for_development/20news-18828/sci.med/58830
#   inflating: files_for_development/20news-18828/sci.med/59175
#   inflating: files_for_development/20news-18828/sci.med/59412
#   inflating: files_for_development/20news-18828/sci.med/59113
#   inflating: files_for_development/20news-18828/sci.med/58846
#   inflating: files_for_development/20news-18828/sci.med/59499
#   inflating: files_for_development/20news-18828/sci.med/59391
#   inflating: files_for_development/20news-18828/sci.med/59545
#   inflating: files_for_development/20news-18828/sci.med/59137
#   inflating: files_for_development/20news-18828/sci.med/59322
#   inflating: files_for_development/20news-18828/sci.med/59256
#   inflating: files_for_development/20news-18828/sci.med/59500
#   inflating: files_for_development/20news-18828/sci.med/58138
#   inflating: files_for_development/20news-18828/sci.med/59003
#   inflating: files_for_development/20news-18828/sci.med/58898
#   inflating: files_for_development/20news-18828/sci.med/59577
#   inflating: files_for_development/20news-18828/sci.med/59234
#   inflating: files_for_development/20news-18828/sci.med/59539
#   inflating: files_for_development/20news-18828/sci.med/59075
#   inflating: files_for_development/20news-18828/sci.med/58768
#   inflating: files_for_development/20news-18828/sci.med/58155
#   inflating: files_for_development/20news-18828/sci.med/58069
#   inflating: files_for_development/20news-18828/sci.med/58980
#   inflating: files_for_development/20news-18828/sci.med/59427
#   inflating: files_for_development/20news-18828/sci.med/59011
#   inflating: files_for_development/20news-18828/sci.med/59020
#   inflating: files_for_development/20news-18828/sci.med/59408
#   inflating: files_for_development/20news-18828/sci.med/58055
#   inflating: files_for_development/20news-18828/sci.med/59424
#   inflating: files_for_development/20news-18828/sci.med/59538
#   inflating: files_for_development/20news-18828/sci.med/59095
#   inflating: files_for_development/20news-18828/sci.med/58046
#   inflating: files_for_development/20news-18828/sci.med/58098
#   inflating: files_for_development/20news-18828/sci.med/59419
#   inflating: files_for_development/20news-18828/sci.med/58891
#   inflating: files_for_development/20news-18828/sci.med/59517
#   inflating: files_for_development/20news-18828/sci.med/59080
#   inflating: files_for_development/20news-18828/sci.med/59438
#   inflating: files_for_development/20news-18828/sci.med/59407
#   inflating: files_for_development/20news-18828/sci.med/58765
#   inflating: files_for_development/20news-18828/sci.med/58913
#   inflating: files_for_development/20news-18828/sci.med/59010
#   inflating: files_for_development/20news-18828/sci.med/58991
#   inflating: files_for_development/20news-18828/sci.med/59181
#   inflating: files_for_development/20news-18828/sci.med/58962
#   inflating: files_for_development/20news-18828/sci.med/59357
#   inflating: files_for_development/20news-18828/sci.med/59298
#   inflating: files_for_development/20news-18828/sci.med/59327
#   inflating: files_for_development/20news-18828/sci.med/58149
#   inflating: files_for_development/20news-18828/sci.med/58078
#   inflating: files_for_development/20news-18828/sci.med/58856
#   inflating: files_for_development/20news-18828/sci.med/59119
#   inflating: files_for_development/20news-18828/sci.med/59643
#   inflating: files_for_development/20news-18828/sci.med/59268
#   inflating: files_for_development/20news-18828/sci.med/58119
#   inflating: files_for_development/20news-18828/sci.med/59476
#   inflating: files_for_development/20news-18828/sci.med/58077
#   inflating: files_for_development/20news-18828/sci.med/59138
#   inflating: files_for_development/20news-18828/sci.med/59360
#   inflating: files_for_development/20news-18828/sci.med/59568
#   inflating: files_for_development/20news-18828/sci.med/58113
#   inflating: files_for_development/20news-18828/sci.med/59013
#   inflating: files_for_development/20news-18828/sci.med/58885
#   inflating: files_for_development/20news-18828/sci.med/59132
#   inflating: files_for_development/20news-18828/sci.med/59278
#   inflating: files_for_development/20news-18828/sci.med/58823
#   inflating: files_for_development/20news-18828/sci.med/58911
#   inflating: files_for_development/20news-18828/sci.med/59403
#   inflating: files_for_development/20news-18828/sci.med/59082
#   inflating: files_for_development/20news-18828/sci.med/58799
#   inflating: files_for_development/20news-18828/sci.med/59491
#   inflating: files_for_development/20news-18828/sci.med/59306
#   inflating: files_for_development/20news-18828/sci.med/58060
#   inflating: files_for_development/20news-18828/sci.med/59063
#   inflating: files_for_development/20news-18828/sci.med/59114
#   inflating: files_for_development/20news-18828/sci.med/59629
#   inflating: files_for_development/20news-18828/sci.med/58929
#   inflating: files_for_development/20news-18828/sci.med/59149
#   inflating: files_for_development/20news-18828/sci.med/59079
#   inflating: files_for_development/20news-18828/sci.med/59494
#   inflating: files_for_development/20news-18828/sci.med/59371
#   inflating: files_for_development/20news-18828/sci.med/58080
#   inflating: files_for_development/20news-18828/sci.med/58820
#   inflating: files_for_development/20news-18828/sci.med/59044
#   inflating: files_for_development/20news-18828/sci.med/59370
#   inflating: files_for_development/20news-18828/sci.med/59420
#   inflating: files_for_development/20news-18828/sci.med/59065
#   inflating: files_for_development/20news-18828/sci.med/59522
#   inflating: files_for_development/20news-18828/sci.med/59024
#   inflating: files_for_development/20news-18828/sci.med/59172
#   inflating: files_for_development/20news-18828/sci.med/58883
#   inflating: files_for_development/20news-18828/sci.med/59393
#   inflating: files_for_development/20news-18828/sci.med/58112
#   inflating: files_for_development/20news-18828/sci.med/58987
#   inflating: files_for_development/20news-18828/sci.med/58045
#   inflating: files_for_development/20news-18828/sci.med/59226
#   inflating: files_for_development/20news-18828/sci.med/59098
#   inflating: files_for_development/20news-18828/sci.med/58950
#   inflating: files_for_development/20news-18828/sci.med/59241
#   inflating: files_for_development/20news-18828/sci.med/59142
#   inflating: files_for_development/20news-18828/sci.med/59091
#   inflating: files_for_development/20news-18828/sci.med/59575
#   inflating: files_for_development/20news-18828/sci.med/58816
#   inflating: files_for_development/20news-18828/sci.med/59071
#   inflating: files_for_development/20news-18828/sci.med/58109
#   inflating: files_for_development/20news-18828/sci.med/59351
#   inflating: files_for_development/20news-18828/sci.med/59016
#   inflating: files_for_development/20news-18828/sci.med/58963
#   inflating: files_for_development/20news-18828/sci.med/59394
#   inflating: files_for_development/20news-18828/sci.med/59627
#   inflating: files_for_development/20news-18828/sci.med/59090
#   inflating: files_for_development/20news-18828/sci.med/59301
#   inflating: files_for_development/20news-18828/sci.med/59414
#   inflating: files_for_development/20news-18828/sci.med/59326
#   inflating: files_for_development/20news-18828/sci.med/58917
#   inflating: files_for_development/20news-18828/sci.med/59218
#   inflating: files_for_development/20news-18828/sci.med/58981
#   inflating: files_for_development/20news-18828/sci.med/59329
#   inflating: files_for_development/20news-18828/sci.med/59603
#   inflating: files_for_development/20news-18828/sci.med/59413
#   inflating: files_for_development/20news-18828/sci.med/59217
#   inflating: files_for_development/20news-18828/sci.med/59631
#   inflating: files_for_development/20news-18828/sci.med/59228
#   inflating: files_for_development/20news-18828/sci.med/59074
#   inflating: files_for_development/20news-18828/sci.med/58139
#   inflating: files_for_development/20news-18828/sci.med/59425
#   inflating: files_for_development/20news-18828/sci.med/58901
#   inflating: files_for_development/20news-18828/sci.med/59401
#   inflating: files_for_development/20news-18828/sci.med/59572
#   inflating: files_for_development/20news-18828/sci.med/59576
#   inflating: files_for_development/20news-18828/sci.med/59203
#   inflating: files_for_development/20news-18828/sci.med/59280
#   inflating: files_for_development/20news-18828/sci.med/59411
#   inflating: files_for_development/20news-18828/sci.med/59029
#   inflating: files_for_development/20news-18828/sci.med/58831
#   inflating: files_for_development/20news-18828/sci.med/58809
#   inflating: files_for_development/20news-18828/sci.med/58800
#   inflating: files_for_development/20news-18828/sci.med/58797
#   inflating: files_for_development/20news-18828/sci.med/58906
#   inflating: files_for_development/20news-18828/sci.med/58888
#   inflating: files_for_development/20news-18828/sci.med/59585
#   inflating: files_for_development/20news-18828/sci.med/59152
#   inflating: files_for_development/20news-18828/sci.med/59525
#   inflating: files_for_development/20news-18828/sci.med/59004
#   inflating: files_for_development/20news-18828/sci.med/58970
#   inflating: files_for_development/20news-18828/sci.med/59359
#   inflating: files_for_development/20news-18828/sci.med/58974
#   inflating: files_for_development/20news-18828/sci.med/59031
#   inflating: files_for_development/20news-18828/sci.med/58946
#   inflating: files_for_development/20news-18828/sci.med/59173
#   inflating: files_for_development/20news-18828/sci.med/59321
#   inflating: files_for_development/20news-18828/sci.med/59015
#   inflating: files_for_development/20news-18828/sci.med/58935
#   inflating: files_for_development/20news-18828/sci.med/59388
#   inflating: files_for_development/20news-18828/sci.med/58759
#   inflating: files_for_development/20news-18828/sci.med/58790
#   inflating: files_for_development/20news-18828/sci.med/59469
#   inflating: files_for_development/20news-18828/sci.med/59266
#   inflating: files_for_development/20news-18828/sci.med/59554
#   inflating: files_for_development/20news-18828/sci.med/58097
#   inflating: files_for_development/20news-18828/sci.med/59373
#   inflating: files_for_development/20news-18828/sci.med/59530
#   inflating: files_for_development/20news-18828/sci.med/59574
#   inflating: files_for_development/20news-18828/sci.med/59250
#   inflating: files_for_development/20news-18828/sci.med/59398
#   inflating: files_for_development/20news-18828/sci.med/59447
#   inflating: files_for_development/20news-18828/sci.med/59374
#   inflating: files_for_development/20news-18828/sci.med/59122
#   inflating: files_for_development/20news-18828/sci.med/59159
#   inflating: files_for_development/20news-18828/sci.med/59454
#   inflating: files_for_development/20news-18828/sci.med/59034
#   inflating: files_for_development/20news-18828/sci.med/59646
#   inflating: files_for_development/20news-18828/sci.med/59409
#   inflating: files_for_development/20news-18828/sci.med/59183
#   inflating: files_for_development/20news-18828/sci.med/58964
#   inflating: files_for_development/20news-18828/sci.med/59458
#   inflating: files_for_development/20news-18828/sci.med/59236
#   inflating: files_for_development/20news-18828/sci.med/59597
#   inflating: files_for_development/20news-18828/sci.med/59025
#   inflating: files_for_development/20news-18828/sci.med/59637
#   inflating: files_for_development/20news-18828/sci.med/58942
#   inflating: files_for_development/20news-18828/sci.med/59193
#   inflating: files_for_development/20news-18828/sci.med/59239
#   inflating: files_for_development/20news-18828/sci.med/59072
#   inflating: files_for_development/20news-18828/sci.med/59297
#   inflating: files_for_development/20news-18828/sci.med/59546
#   inflating: files_for_development/20news-18828/sci.med/59267
#   inflating: files_for_development/20news-18828/sci.med/59012
#   inflating: files_for_development/20news-18828/sci.med/59361
#   inflating: files_for_development/20news-18828/sci.med/58147
#   inflating: files_for_development/20news-18828/sci.med/59146
#   inflating: files_for_development/20news-18828/sci.med/59258
#   inflating: files_for_development/20news-18828/sci.med/59084
#   inflating: files_for_development/20news-18828/sci.med/58968
#   inflating: files_for_development/20news-18828/sci.med/59339
#   inflating: files_for_development/20news-18828/sci.med/59372
#   inflating: files_for_development/20news-18828/sci.med/59094
#   inflating: files_for_development/20news-18828/sci.med/58128
#   inflating: files_for_development/20news-18828/sci.med/58997
#   inflating: files_for_development/20news-18828/sci.med/59334
#   inflating: files_for_development/20news-18828/sci.med/59598
#   inflating: files_for_development/20news-18828/sci.med/59163
#   inflating: files_for_development/20news-18828/sci.med/59635
#   inflating: files_for_development/20news-18828/sci.med/59276
#   inflating: files_for_development/20news-18828/sci.med/59573
#   inflating: files_for_development/20news-18828/sci.med/59052
#   inflating: files_for_development/20news-18828/sci.med/58084
#   inflating: files_for_development/20news-18828/sci.med/59346
#   inflating: files_for_development/20news-18828/sci.med/59115
#   inflating: files_for_development/20news-18828/sci.med/59330
#   inflating: files_for_development/20news-18828/sci.med/58096
#   inflating: files_for_development/20news-18828/sci.med/59442
#   inflating: files_for_development/20news-18828/sci.med/58763
#   inflating: files_for_development/20news-18828/sci.med/59302
#   inflating: files_for_development/20news-18828/sci.med/59340
#   inflating: files_for_development/20news-18828/sci.med/58926
#   inflating: files_for_development/20news-18828/sci.med/58903
#   inflating: files_for_development/20news-18828/sci.med/59106
#   inflating: files_for_development/20news-18828/sci.med/59501
#   inflating: files_for_development/20news-18828/sci.med/58764
#   inflating: files_for_development/20news-18828/sci.med/59141
#   inflating: files_for_development/20news-18828/sci.med/59482
#   inflating: files_for_development/20news-18828/sci.med/58870
#   inflating: files_for_development/20news-18828/sci.med/59200
#   inflating: files_for_development/20news-18828/sci.med/58864
#   inflating: files_for_development/20news-18828/sci.med/59582
#   inflating: files_for_development/20news-18828/sci.med/59504
#   inflating: files_for_development/20news-18828/sci.med/59317
#   inflating: files_for_development/20news-18828/sci.med/58144
#   inflating: files_for_development/20news-18828/sci.med/58868
#   inflating: files_for_development/20news-18828/sci.med/58127
#   inflating: files_for_development/20news-18828/sci.med/58918
#   inflating: files_for_development/20news-18828/sci.med/59232
#   inflating: files_for_development/20news-18828/sci.med/58076
#   inflating: files_for_development/20news-18828/sci.med/58806
#   inflating: files_for_development/20news-18828/sci.med/59375
#   inflating: files_for_development/20news-18828/sci.med/59292
#   inflating: files_for_development/20news-18828/sci.med/59431
#   inflating: files_for_development/20news-18828/sci.med/59308
#   inflating: files_for_development/20news-18828/sci.med/59202
#   inflating: files_for_development/20news-18828/sci.med/58875
#   inflating: files_for_development/20news-18828/sci.med/58059
#   inflating: files_for_development/20news-18828/sci.med/59118
#   inflating: files_for_development/20news-18828/sci.med/58992
#   inflating: files_for_development/20news-18828/sci.med/58114
#   inflating: files_for_development/20news-18828/sci.med/58960
#   inflating: files_for_development/20news-18828/sci.med/59147
#   inflating: files_for_development/20news-18828/sci.med/59567
#   inflating: files_for_development/20news-18828/sci.med/59578
#   inflating: files_for_development/20news-18828/sci.med/58824
#   inflating: files_for_development/20news-18828/sci.med/58779
#   inflating: files_for_development/20news-18828/sci.med/59638
#   inflating: files_for_development/20news-18828/sci.med/59560
#   inflating: files_for_development/20news-18828/sci.med/59417
#   inflating: files_for_development/20news-18828/sci.med/59196
#   inflating: files_for_development/20news-18828/sci.med/58854
#   inflating: files_for_development/20news-18828/sci.med/59290
#   inflating: files_for_development/20news-18828/sci.med/59621
#   inflating: files_for_development/20news-18828/sci.med/58783
#   inflating: files_for_development/20news-18828/sci.med/59416
#   inflating: files_for_development/20news-18828/sci.med/59222
#   inflating: files_for_development/20news-18828/sci.med/59362
#   inflating: files_for_development/20news-18828/sci.med/58915
#   inflating: files_for_development/20news-18828/sci.med/59067
#   inflating: files_for_development/20news-18828/sci.med/59429
#   inflating: files_for_development/20news-18828/sci.med/59028
#   inflating: files_for_development/20news-18828/sci.med/59436
#   inflating: files_for_development/20news-18828/sci.med/59601
#   inflating: files_for_development/20news-18828/sci.med/58925
#   inflating: files_for_development/20news-18828/sci.med/59579
#   inflating: files_for_development/20news-18828/sci.med/59033
#   inflating: files_for_development/20news-18828/sci.med/58930
#   inflating: files_for_development/20news-18828/sci.med/59311
#   inflating: files_for_development/20news-18828/sci.med/59392
#   inflating: files_for_development/20news-18828/sci.med/59464
#   inflating: files_for_development/20news-18828/sci.med/58146
#   inflating: files_for_development/20news-18828/sci.med/59041
#   inflating: files_for_development/20news-18828/sci.med/59380
#   inflating: files_for_development/20news-18828/sci.med/59180
#   inflating: files_for_development/20news-18828/sci.med/58872
#   inflating: files_for_development/20news-18828/sci.med/59332
#   inflating: files_for_development/20news-18828/sci.med/58762
#   inflating: files_for_development/20news-18828/sci.med/59600
#   inflating: files_for_development/20news-18828/sci.med/58133
#   inflating: files_for_development/20news-18828/sci.med/59605
#   inflating: files_for_development/20news-18828/sci.med/58874
#   inflating: files_for_development/20news-18828/sci.med/59179
#   inflating: files_for_development/20news-18828/sci.med/58988
#   inflating: files_for_development/20news-18828/sci.med/58819
#   inflating: files_for_development/20news-18828/sci.med/59368
#   inflating: files_for_development/20news-18828/sci.med/59369
#   inflating: files_for_development/20news-18828/sci.med/59261
#   inflating: files_for_development/20news-18828/sci.med/59162
#   inflating: files_for_development/20news-18828/sci.med/58983
#   inflating: files_for_development/20news-18828/sci.med/59487
#   inflating: files_for_development/20news-18828/sci.med/58952
#   inflating: files_for_development/20news-18828/sci.med/59087
#   inflating: files_for_development/20news-18828/sci.med/58916
#   inflating: files_for_development/20news-18828/sci.med/59081
#   inflating: files_for_development/20news-18828/sci.med/58832
#   inflating: files_for_development/20news-18828/sci.med/59384
#   inflating: files_for_development/20news-18828/sci.med/58909
#   inflating: files_for_development/20news-18828/sci.med/59021
#   inflating: files_for_development/20news-18828/sci.med/59109
#   inflating: files_for_development/20news-18828/sci.med/58151
#   inflating: files_for_development/20news-18828/sci.med/58140
#   inflating: files_for_development/20news-18828/sci.med/59513
#   inflating: files_for_development/20news-18828/sci.med/59456
#   inflating: files_for_development/20news-18828/sci.med/58089
#   inflating: files_for_development/20news-18828/sci.med/59257
#   inflating: files_for_development/20news-18828/sci.med/59008
#   inflating: files_for_development/20news-18828/sci.med/59205
#   inflating: files_for_development/20news-18828/sci.med/59387
#   inflating: files_for_development/20news-18828/sci.med/59331
#   inflating: files_for_development/20news-18828/sci.med/59204
#   inflating: files_for_development/20news-18828/sci.med/59541
#   inflating: files_for_development/20news-18828/sci.med/59167
#   inflating: files_for_development/20news-18828/sci.med/58784
#   inflating: files_for_development/20news-18828/sci.med/58782
#   inflating: files_for_development/20news-18828/sci.med/58919
#   inflating: files_for_development/20news-18828/sci.med/59488
#   inflating: files_for_development/20news-18828/sci.med/58975
#   inflating: files_for_development/20news-18828/sci.med/59551
#   inflating: files_for_development/20news-18828/sci.med/59589
#   inflating: files_for_development/20news-18828/sci.med/59581
#   inflating: files_for_development/20news-18828/sci.med/59644
#   inflating: files_for_development/20news-18828/sci.med/59194
#   inflating: files_for_development/20news-18828/sci.med/59383
#   inflating: files_for_development/20news-18828/sci.med/59047
#   inflating: files_for_development/20news-18828/sci.med/59547
#   inflating: files_for_development/20news-18828/sci.med/58775
#   inflating: files_for_development/20news-18828/sci.med/59524
#   inflating: files_for_development/20news-18828/sci.med/58061
#   inflating: files_for_development/20news-18828/sci.med/58774
#   inflating: files_for_development/20news-18828/sci.med/59451
#   inflating: files_for_development/20news-18828/sci.med/59057
#   inflating: files_for_development/20news-18828/sci.med/58861
#   inflating: files_for_development/20news-18828/sci.med/58982
#   inflating: files_for_development/20news-18828/sci.med/58817
#   inflating: files_for_development/20news-18828/sci.med/58957
#   inflating: files_for_development/20news-18828/sci.med/58071
#   inflating: files_for_development/20news-18828/sci.med/58993
#   inflating: files_for_development/20news-18828/sci.med/59303
#   inflating: files_for_development/20news-18828/sci.med/59023
#   inflating: files_for_development/20news-18828/sci.med/59066
#   inflating: files_for_development/20news-18828/sci.med/59588
#   inflating: files_for_development/20news-18828/sci.med/59421
#   inflating: files_for_development/20news-18828/sci.med/59562
#   inflating: files_for_development/20news-18828/sci.med/59580
#   inflating: files_for_development/20news-18828/sci.med/58976
#   inflating: files_for_development/20news-18828/sci.med/59231
#   inflating: files_for_development/20news-18828/sci.med/59273
#   inflating: files_for_development/20news-18828/sci.med/59344
#   inflating: files_for_development/20news-18828/sci.med/58047
#   inflating: files_for_development/20news-18828/sci.med/59101
#   inflating: files_for_development/20news-18828/sci.med/58894
#   inflating: files_for_development/20news-18828/sci.med/58811
#   inflating: files_for_development/20news-18828/sci.med/59594
#   inflating: files_for_development/20news-18828/sci.med/59475
#   inflating: files_for_development/20news-18828/sci.med/58967
#   inflating: files_for_development/20news-18828/sci.med/58057
#   inflating: files_for_development/20news-18828/sci.med/59221
#   inflating: files_for_development/20news-18828/sci.med/58932
#   inflating: files_for_development/20news-18828/sci.med/59474
#   inflating: files_for_development/20news-18828/sci.med/59510
#   inflating: files_for_development/20news-18828/sci.med/59093
#   inflating: files_for_development/20news-18828/sci.med/58895
#   inflating: files_for_development/20news-18828/sci.med/58760
#   inflating: files_for_development/20news-18828/sci.med/59291
#   inflating: files_for_development/20news-18828/sci.med/59484
#   inflating: files_for_development/20news-18828/sci.med/59216
#   inflating: files_for_development/20news-18828/sci.med/59157
#   inflating: files_for_development/20news-18828/sci.med/59269
#   inflating: files_for_development/20news-18828/sci.med/59272
#   inflating: files_for_development/20news-18828/sci.med/58761
#   inflating: files_for_development/20news-18828/sci.med/58085
#   inflating: files_for_development/20news-18828/sci.med/58972
#   inflating: files_for_development/20news-18828/sci.med/58106
#   inflating: files_for_development/20news-18828/sci.med/59160
#   inflating: files_for_development/20news-18828/sci.med/59009
#   inflating: files_for_development/20news-18828/sci.med/59385
#   inflating: files_for_development/20news-18828/sci.med/58858
#   inflating: files_for_development/20news-18828/sci.med/59640
#   inflating: files_for_development/20news-18828/sci.med/59503
#   inflating: files_for_development/20news-18828/sci.med/59377
#   inflating: files_for_development/20news-18828/sci.med/59158
#   inflating: files_for_development/20news-18828/sci.med/58092
#   inflating: files_for_development/20news-18828/sci.med/59452
#   inflating: files_for_development/20news-18828/sci.med/59176
#   inflating: files_for_development/20news-18828/sci.med/59259
#   inflating: files_for_development/20news-18828/sci.med/58083
#   inflating: files_for_development/20news-18828/sci.med/59178
#   inflating: files_for_development/20news-18828/sci.med/59604
#   inflating: files_for_development/20news-18828/sci.med/59064
#   inflating: files_for_development/20news-18828/sci.med/58758
#   inflating: files_for_development/20news-18828/sci.med/58081
#   inflating: files_for_development/20news-18828/sci.med/58141
#   inflating: files_for_development/20news-18828/sci.med/59165
#   inflating: files_for_development/20news-18828/sci.med/59471
#   inflating: files_for_development/20news-18828/sci.med/58088
#   inflating: files_for_development/20news-18828/sci.med/58074
#   inflating: files_for_development/20news-18828/sci.med/58857
#   inflating: files_for_development/20news-18828/sci.med/59061
#   inflating: files_for_development/20news-18828/sci.med/59549
#   inflating: files_for_development/20news-18828/sci.med/58949
#   inflating: files_for_development/20news-18828/sci.med/58940
#   inflating: files_for_development/20news-18828/sci.med/59316
#   inflating: files_for_development/20news-18828/sci.med/59418
#   inflating: files_for_development/20news-18828/sci.med/59625
#   inflating: files_for_development/20news-18828/sci.med/58829
#   inflating: files_for_development/20news-18828/sci.med/58989
#   inflating: files_for_development/20news-18828/sci.med/58803
#   inflating: files_for_development/20news-18828/sci.med/59477
#   inflating: files_for_development/20news-18828/sci.med/59270
#   inflating: files_for_development/20news-18828/sci.med/59550
#   inflating: files_for_development/20news-18828/sci.med/58569
#   inflating: files_for_development/20news-18828/sci.med/59348
#   inflating: files_for_development/20news-18828/sci.med/59096
#   inflating: files_for_development/20news-18828/sci.med/59356
#   inflating: files_for_development/20news-18828/sci.med/59036
#   inflating: files_for_development/20news-18828/sci.med/59350
#   inflating: files_for_development/20news-18828/sci.med/59460
#   inflating: files_for_development/20news-18828/sci.med/58094
#   inflating: files_for_development/20news-18828/sci.med/59529
#   inflating: files_for_development/20news-18828/sci.med/58091
#   inflating: files_for_development/20news-18828/sci.med/59030
#   inflating: files_for_development/20news-18828/sci.med/59533
#   inflating: files_for_development/20news-18828/sci.med/59105
#   inflating: files_for_development/20news-18828/sci.med/59049
# ...
#   inflating: files_for_development/20news-18828/talk.religion.misc/83535
#   inflating: files_for_development/20news-18828/talk.religion.misc/83845
#   inflating: files_for_development/20news-18828/talk.religion.misc/83732
#   inflating: files_for_development/20news-18828/talk.religion.misc/84146
#   inflating: files_for_development/20news-18828/talk.religion.misc/84165
#   inflating: files_for_development/20news-18828/talk.religion.misc/84398
#   inflating: files_for_development/20news-18828/talk.religion.misc/83572
#   inflating: files_for_development/20news-18828/talk.religion.misc/84122
#   inflating: files_for_development/20news-18828/talk.religion.misc/84270
#   inflating: files_for_development/20news-18828/talk.religion.misc/84236
#   inflating: files_for_development/20news-18828/talk.religion.misc/83932
#   inflating: files_for_development/20news-18828/talk.religion.misc/83562
#   inflating: files_for_development/20news-18828/talk.religion.misc/83807
#   inflating: files_for_development/20news-18828/talk.religion.misc/83957
#   inflating: files_for_development/20news-18828/talk.religion.misc/84346
#   inflating: files_for_development/20news-18828/talk.religion.misc/84087
#   inflating: files_for_development/20news-18828/talk.religion.misc/84268
#   inflating: files_for_development/20news-18828/talk.religion.misc/84231
#   inflating: files_for_development/20news-18828/talk.religion.misc/84255
#   inflating: files_for_development/20news-18828/talk.religion.misc/84430
#   inflating: files_for_development/20news-18828/talk.religion.misc/84139
#   inflating: files_for_development/20news-18828/talk.religion.misc/84314
#   inflating: files_for_development/20news-18828/talk.religion.misc/84202
#   inflating: files_for_development/20news-18828/talk.religion.misc/82799
#   inflating: files_for_development/20news-18828/talk.religion.misc/84306
#   inflating: files_for_development/20news-18828/talk.religion.misc/83937
#   inflating: files_for_development/20news-18828/talk.religion.misc/84182
#   inflating: files_for_development/20news-18828/talk.religion.misc/84265
#   inflating: files_for_development/20news-18828/talk.religion.misc/84281
#   inflating: files_for_development/20news-18828/talk.religion.misc/84073
#   inflating: files_for_development/20news-18828/talk.religion.misc/83528
#   inflating: files_for_development/20news-18828/talk.religion.misc/84274
#   inflating: files_for_development/20news-18828/talk.religion.misc/83547
#   inflating: files_for_development/20news-18828/talk.religion.misc/84227
#   inflating: files_for_development/20news-18828/talk.religion.misc/84399
#   inflating: files_for_development/20news-18828/talk.religion.misc/84560
#   inflating: files_for_development/20news-18828/talk.religion.misc/82804
#   inflating: files_for_development/20news-18828/talk.religion.misc/83805
#   inflating: files_for_development/20news-18828/talk.religion.misc/84164
#   inflating: files_for_development/20news-18828/talk.religion.misc/84301
#   inflating: files_for_development/20news-18828/talk.religion.misc/83744
#   inflating: files_for_development/20news-18828/talk.religion.misc/83463
#   inflating: files_for_development/20news-18828/talk.religion.misc/83977
#   inflating: files_for_development/20news-18828/talk.religion.misc/84130
#   inflating: files_for_development/20news-18828/talk.religion.misc/84436
#   inflating: files_for_development/20news-18828/talk.religion.misc/84083
#   inflating: files_for_development/20news-18828/talk.religion.misc/84271
#   inflating: files_for_development/20news-18828/talk.religion.misc/83659
#   inflating: files_for_development/20news-18828/talk.religion.misc/84151
#   inflating: files_for_development/20news-18828/talk.religion.misc/84113
#   inflating: files_for_development/20news-18828/talk.religion.misc/83852
#   inflating: files_for_development/20news-18828/talk.religion.misc/83895
#   inflating: files_for_development/20news-18828/talk.religion.misc/83451
#   inflating: files_for_development/20news-18828/talk.religion.misc/84440
#   inflating: files_for_development/20news-18828/talk.religion.misc/84221
#   inflating: files_for_development/20news-18828/talk.religion.misc/84137
#   inflating: files_for_development/20news-18828/talk.religion.misc/83660
#   inflating: files_for_development/20news-18828/talk.religion.misc/84077
#   inflating: files_for_development/20news-18828/talk.religion.misc/84261
#   inflating: files_for_development/20news-18828/talk.religion.misc/84082
#   inflating: files_for_development/20news-18828/talk.religion.misc/84125
#   inflating: files_for_development/20news-18828/talk.religion.misc/83608
#   inflating: files_for_development/20news-18828/talk.religion.misc/84206
#   inflating: files_for_development/20news-18828/talk.religion.misc/84192
#   inflating: files_for_development/20news-18828/talk.religion.misc/84193
#   inflating: files_for_development/20news-18828/talk.religion.misc/83944
#   inflating: files_for_development/20news-18828/talk.religion.misc/84064
#   inflating: files_for_development/20news-18828/talk.religion.misc/83976
#   inflating: files_for_development/20news-18828/talk.religion.misc/83658
#   inflating: files_for_development/20news-18828/talk.religion.misc/84307
#   inflating: files_for_development/20news-18828/talk.religion.misc/83529
#   inflating: files_for_development/20news-18828/talk.religion.misc/83884
#   inflating: files_for_development/20news-18828/talk.religion.misc/84069
#   inflating: files_for_development/20news-18828/talk.religion.misc/83513
#   inflating: files_for_development/20news-18828/talk.religion.misc/84198
#   inflating: files_for_development/20news-18828/talk.religion.misc/84053
#   inflating: files_for_development/20news-18828/talk.religion.misc/83919
#   inflating: files_for_development/20news-18828/talk.religion.misc/82807
#   inflating: files_for_development/20news-18828/talk.religion.misc/83776
#   inflating: files_for_development/20news-18828/talk.religion.misc/84449
#   inflating: files_for_development/20news-18828/talk.religion.misc/83477
#   inflating: files_for_development/20news-18828/talk.religion.misc/83602
#   inflating: files_for_development/20news-18828/talk.religion.misc/84018
#   inflating: files_for_development/20news-18828/talk.religion.misc/84209
#   inflating: files_for_development/20news-18828/talk.religion.misc/83651
#   inflating: files_for_development/20news-18828/talk.religion.misc/84060
#   inflating: files_for_development/20news-18828/talk.religion.misc/84323
#   inflating: files_for_development/20news-18828/talk.religion.misc/84332
#   inflating: files_for_development/20news-18828/talk.religion.misc/84259
#   inflating: files_for_development/20news-18828/talk.religion.misc/83931
#   inflating: files_for_development/20news-18828/talk.religion.misc/84056
#   inflating: files_for_development/20news-18828/talk.religion.misc/84442
#   inflating: files_for_development/20news-18828/talk.religion.misc/82787
#   inflating: files_for_development/20news-18828/talk.religion.misc/84195
#   inflating: files_for_development/20news-18828/talk.religion.misc/84101
#   inflating: files_for_development/20news-18828/talk.religion.misc/84511
#   inflating: files_for_development/20news-18828/talk.religion.misc/84201
#   inflating: files_for_development/20news-18828/talk.religion.misc/84316
#   inflating: files_for_development/20news-18828/talk.religion.misc/84152
#   inflating: files_for_development/20news-18828/talk.religion.misc/84304
#   inflating: files_for_development/20news-18828/talk.religion.misc/82784
#   inflating: files_for_development/20news-18828/talk.religion.misc/83621
#   inflating: files_for_development/20news-18828/talk.religion.misc/82818
#   inflating: files_for_development/20news-18828/talk.religion.misc/84178
#   inflating: files_for_development/20news-18828/talk.religion.misc/84159
#   inflating: files_for_development/20news-18828/talk.religion.misc/82782
#   inflating: files_for_development/20news-18828/talk.religion.misc/84235
#   inflating: files_for_development/20news-18828/talk.religion.misc/83476
#   inflating: files_for_development/20news-18828/talk.religion.misc/84197
#   inflating: files_for_development/20news-18828/talk.religion.misc/82785
#   inflating: files_for_development/20news-18828/talk.religion.misc/84170
#   inflating: files_for_development/20news-18828/talk.religion.misc/82795
#   inflating: files_for_development/20news-18828/talk.religion.misc/84232
#   inflating: files_for_development/20news-18828/talk.religion.misc/82771
#   inflating: files_for_development/20news-18828/talk.religion.misc/83624
#   inflating: files_for_development/20news-18828/talk.religion.misc/83609
#   inflating: files_for_development/20news-18828/talk.religion.misc/84334
#   inflating: files_for_development/20news-18828/talk.religion.misc/84310
#   inflating: files_for_development/20news-18828/talk.religion.misc/84238
#   inflating: files_for_development/20news-18828/talk.religion.misc/83687
#   inflating: files_for_development/20news-18828/talk.religion.misc/84239
#   inflating: files_for_development/20news-18828/talk.religion.misc/83630
#   inflating: files_for_development/20news-18828/talk.religion.misc/83568
#   inflating: files_for_development/20news-18828/talk.religion.misc/83713
#   inflating: files_for_development/20news-18828/talk.religion.misc/83467
#   inflating: files_for_development/20news-18828/talk.religion.misc/83504
#   inflating: files_for_development/20news-18828/talk.religion.misc/84133
#   inflating: files_for_development/20news-18828/talk.religion.misc/84187
#   inflating: files_for_development/20news-18828/talk.religion.misc/84557
#   inflating: files_for_development/20news-18828/talk.religion.misc/83592
#   inflating: files_for_development/20news-18828/talk.religion.misc/84284
#   inflating: files_for_development/20news-18828/talk.religion.misc/83848
#   inflating: files_for_development/20news-18828/talk.religion.misc/83830
#   inflating: files_for_development/20news-18828/talk.religion.misc/83500
#   inflating: files_for_development/20news-18828/talk.religion.misc/83517
#   inflating: files_for_development/20news-18828/talk.religion.misc/84326
#   inflating: files_for_development/20news-18828/talk.religion.misc/84506
#   inflating: files_for_development/20news-18828/talk.religion.misc/83471
#   inflating: files_for_development/20news-18828/talk.religion.misc/84343
#   inflating: files_for_development/20news-18828/talk.religion.misc/82763
#   inflating: files_for_development/20news-18828/talk.religion.misc/84127
#   inflating: files_for_development/20news-18828/talk.religion.misc/82772
#   inflating: files_for_development/20news-18828/talk.religion.misc/83650
#   inflating: files_for_development/20news-18828/talk.religion.misc/84004
#   inflating: files_for_development/20news-18828/talk.religion.misc/83714
#   inflating: files_for_development/20news-18828/talk.religion.misc/84448
#   inflating: files_for_development/20news-18828/talk.religion.misc/84222
#   inflating: files_for_development/20news-18828/talk.religion.misc/83701
#   inflating: files_for_development/20news-18828/talk.religion.misc/84319
#   inflating: files_for_development/20news-18828/talk.religion.misc/83516
#   inflating: files_for_development/20news-18828/talk.religion.misc/83518
#   inflating: files_for_development/20news-18828/talk.religion.misc/84294
#   inflating: files_for_development/20news-18828/talk.religion.misc/84229
#   inflating: files_for_development/20news-18828/talk.religion.misc/84357
#   inflating: files_for_development/20news-18828/talk.religion.misc/84312
#   inflating: files_for_development/20news-18828/talk.religion.misc/83781
#   inflating: files_for_development/20news-18828/talk.religion.misc/84300
#   inflating: files_for_development/20news-18828/talk.religion.misc/83907
#   inflating: files_for_development/20news-18828/talk.religion.misc/84341
#   inflating: files_for_development/20news-18828/talk.religion.misc/83728
#   inflating: files_for_development/20news-18828/talk.religion.misc/83892
#   inflating: files_for_development/20news-18828/talk.religion.misc/83722
#   inflating: files_for_development/20news-18828/talk.religion.misc/84256
#   inflating: files_for_development/20news-18828/talk.religion.misc/83485
#   inflating: files_for_development/20news-18828/talk.religion.misc/84422
#   inflating: files_for_development/20news-18828/talk.religion.misc/84132
#   inflating: files_for_development/20news-18828/talk.religion.misc/84254
#   inflating: files_for_development/20news-18828/talk.religion.misc/84075
#   inflating: files_for_development/20news-18828/talk.religion.misc/84451
#   inflating: files_for_development/20news-18828/talk.religion.misc/84071
#   inflating: files_for_development/20news-18828/talk.religion.misc/83661
#   inflating: files_for_development/20news-18828/talk.religion.misc/84096
#   inflating: files_for_development/20news-18828/talk.religion.misc/83736
#   inflating: files_for_development/20news-18828/talk.religion.misc/83586
#   inflating: files_for_development/20news-18828/talk.religion.misc/84272
#   inflating: files_for_development/20news-18828/talk.religion.misc/84324
#   inflating: files_for_development/20news-18828/talk.religion.misc/83705
#   inflating: files_for_development/20news-18828/talk.religion.misc/84538
#   inflating: files_for_development/20news-18828/talk.religion.misc/83610
#   inflating: files_for_development/20news-18828/talk.religion.misc/83491
#   inflating: files_for_development/20news-18828/talk.religion.misc/84234
#   inflating: files_for_development/20news-18828/talk.religion.misc/84452
#   inflating: files_for_development/20news-18828/talk.religion.misc/84226
#   inflating: files_for_development/20news-18828/talk.religion.misc/84247
#   inflating: files_for_development/20news-18828/talk.religion.misc/82759
#   inflating: files_for_development/20news-18828/talk.religion.misc/83646
#   inflating: files_for_development/20news-18828/talk.religion.misc/84086
#   inflating: files_for_development/20news-18828/talk.religion.misc/83786
#   inflating: files_for_development/20news-18828/talk.religion.misc/84123
#   inflating: files_for_development/20news-18828/talk.religion.misc/83561
#   inflating: files_for_development/20news-18828/talk.religion.misc/82815
#   inflating: files_for_development/20news-18828/talk.religion.misc/83828
#   inflating: files_for_development/20news-18828/talk.religion.misc/84352
#   inflating: files_for_development/20news-18828/talk.religion.misc/83849
#   inflating: files_for_development/20news-18828/talk.religion.misc/84510
#   inflating: files_for_development/20news-18828/talk.religion.misc/84074
#   inflating: files_for_development/20news-18828/talk.religion.misc/84207
#   inflating: files_for_development/20news-18828/talk.religion.misc/84098
#   inflating: files_for_development/20news-18828/talk.religion.misc/84441
#   inflating: files_for_development/20news-18828/talk.religion.misc/83508
#   inflating: files_for_development/20news-18828/talk.religion.misc/84325
#   inflating: files_for_development/20news-18828/talk.religion.misc/84380
#   inflating: files_for_development/20news-18828/talk.religion.misc/84054
#   inflating: files_for_development/20news-18828/talk.religion.misc/83725
#   inflating: files_for_development/20news-18828/talk.religion.misc/83643
#   inflating: files_for_development/20news-18828/talk.religion.misc/84564
#   inflating: files_for_development/20news-18828/talk.religion.misc/84321
#   inflating: files_for_development/20news-18828/talk.religion.misc/84215
#   inflating: files_for_development/20news-18828/talk.religion.misc/84328
#   inflating: files_for_development/20news-18828/talk.religion.misc/84131
#   inflating: files_for_development/20news-18828/talk.religion.misc/84450
#   inflating: files_for_development/20news-18828/talk.religion.misc/83620
# /bin/bash: A: command not found

# %%
'''
Created on Sep 30, 2015

@author: Philip Schulz
'''

import sys

def accuracy_checker(gold, pred):
    
    gold_labels = dict()
    pred_labels = dict()

    try:
        with open(gold) as goldFile:
            for line in goldFile:
                elements = line.split()
                gold_labels[elements[0]] = elements[1]
                
        with open(pred) as pred_file:
            for line in pred_file:
                elements = line.split()
                pred_labels[elements[0]] = elements[1]
    
    except IOError as e:
        print(e)
        print("One of the files does not exist on your computer.")
        sys.exit(0)
        
    if len(gold_labels) != len(pred_labels):
        print ('The lists are of different size. Please make sure to only ' +
        'use equally sized lists.')
        sys.exit(0)
        
    overlap = 0
    for doc, label in gold_labels.items():
        if pred_labels[doc] == label:
            overlap += 1
    
    overlap /= float(len(gold_labels))
    overlap *= 100
    
    print('The overlap between the gold list and the student output is {}%'.format(overlap))

# %%
"""
The file implementing Naive Bayes classifier.
"""
###
# You have to work on this file. Your task is to implement the methods
# marked as TODO.

from collections import Counter
import math
import numpy as np

class NaiveBayes(object):
    '''
    This class implements a naive bayes classifier.
    '''
    
    def __init__(self):
        '''
        Constructor
        '''
        # The following Counter will be used to count the number of text
        # occurrencies per label.
        self.label_counts = Counter()
        # The following dictionary will be used to map labels to Counters. Each of these Counters
        # contains the feature counts given the label.
        self.feature_counts = dict()

        # The following dictionary will be used to collect
        # prior probabilities of labels.
        self.label_probs = dict()
        # The following dictionary will be used to collect feature
        # probabilities given a label.
        self.feature_probs = dict()
        #A set that contains all words encountered during training.
        self.vocabulary = set()

    def train(self, data, label):
        '''
        Train the classifier by counting features in the data set.
        
        :param data: A stream of string data from which to extract features
        :param label: The label of the data
        '''
        features = list()
        for word in data.read().split():
            feature = ''.join(filter(str.isalpha, word)).lower()
        
            if len(feature) > 2 and len(feature) < 11:
                features.append(feature)
        if features != None:
            self.add_feature_counts(features, label)
        # for line in data:
        #     self.add_feature_counts(line.lower().split(), label)
    
    def add_feature_counts(self, features, label):
        '''
        Count the features in a feature list.
        
        :param features: a list of features.
        :param label: the label of the data file from which the features were extracted.
        '''
        # This method updates feature_counts by features given the label. It
        # should also update vocabulary with features.
        # TODO: implement this!
        if label in self.feature_counts:
            self.feature_counts[label].update(features)
        else:
            self.feature_counts[label] = Counter()
            self.feature_counts[label].update(features)
        self.vocabulary.update(features)

    def smooth_feature_counts(self, smoothing=1):
        '''Smooth the collected feature counts

        :param smoothing: The smoothing constant
        '''
        # This method smoothes counts in feature_counts. Check the assignment
        # description on how to do this.
        # Add +1 to all counters
        for label in self.feature_counts:
            self.feature_counts[label].update(list(self.vocabulary)*smoothing)
        
        
    def update_label_count(self,label):
        '''
        Increase the count for the supplied label by 1.
        
        :param label: The label whose count is to be increased.
        '''
        self.label_counts.update([label])
        
    def log_normalise_label_probs(self):
        '''
        Take label counts in label_counts, normalize them to
        probabilities, transform them to logprobs and update label_probs
        with the logprobs.
        '''
        # Take label_counts, and update label_probs.
        # label_probs should have labels as keys. The values are
        # log-probability of each label. The probability is created
        # by normalizing values in label_counts, after that it is
        # log-transformed.
        norm = np.sum(list(self.label_counts.values()))
        for label in self.label_counts:
            self.label_probs[label] = np.log(float(self.label_counts[label]) / norm)

            
    def log_normalise_feature_probs(self):
        '''
        Take feature counts in feature_counts and for each label, normalize
        them to probabilities and turn them into logprobs. update
        feature_probs with the created logprobs.
        '''
        # Take feature_counts, update feature_probs.
        # feature_probs have labels as keys. The values are
        # dictionaries that have features as keys as log-probs as values.
        for label in self.feature_counts:
            self.feature_probs[label] = dict()
            label_norm = np.sum(list(self.feature_counts[label].values()))
            for word in self.vocabulary:
                self.feature_probs[label][word] = np.log(float(self.feature_counts[label][word]) / label_norm)
            

                
    def predict(self, data):
        ''' 
        Predict the most probable label according to the model on a stream of data.
        
        :param data: A stream of string data from which to extract features
        :return: the most probable label for the data (type string)
        '''
        features = [''.join(filter(str.isalpha, word)).lower() for word in data.split()]
        # features = data.lower().split(' ')
        max_prob  = 20000000
        for label in self.label_counts:
            # Bayesss
            p = - self.label_probs[label] - np.sum([self.feature_probs[label][word] for word in features if word in self.vocabulary])
            if p < max_prob:
                max_prob = p
                mp_label = label
        return mp_label

# %%
'''
Created on Sep 23, 2015

@author: Philip Schulz
@modifications: Jakub Dotlacil, April 26, 2018
'''

import sys
import argparse
from datetime import datetime
# TODO: replace by the name of the package that you store these files in
# from naive_bayes import NaiveBayes
from os import listdir, remove, system
from os.path import isfile, join

# TODO: Please write the command that you use to call Python in the terminal here
# (most likely, the command is python or python3)
my_python = ""

def train_model(corpus_dir, classifier):
    '''Train a classifier on a training corpus where labels are provided.

    :param corpus_dir: The path to the training folder
    :param classifier: The classifier to be trained
    '''
    print('Starting training at {}'.format(datetime.now()))

    for directory in listdir(corpus_dir):
        print("Training on label {}".format(directory))
        directory_path = join(corpus_dir, directory)
        for text_file in listdir(directory_path):
            file_path = join(directory_path, text_file)
            classifier.update_label_count(directory)
            try:
                with open(file_path) as data_file:
                    classifier.train(data_file, directory)
            except IOError as e:
                print(e)
                print("It seems that the text_file {} is damaged.".format(text_file))
                sys.exit(0)

    print("Starting to smooth and normalise at {}".format(datetime.now()))
    classifier.smooth_feature_counts()
    classifier.log_normalise_label_probs()
    classifier.log_normalise_feature_probs()

    print("Finished training at {}".format(datetime.now()))

def make_predictions(predictions_file, test_dir, classifier):
    '''Make predictions on data with missing label

    :param predictions_file: The file to which the ouput predictions should be written
    :param test_dir: The path to the directory containing the test items
    :param classifier: A trained classifier
    '''
    print("Start making predictions at {}".format(datetime.now()))
    
    if isfile(predictions_file):
        remove(predictions_file)
    
    for test_file in listdir(test_dir):
        try:
            with open(join(test_dir, test_file)) as test, open(predictions_file, "a") as out:
                prediction = classifier.predict(test.read())
                out.write(test_file + "\t{}\n".format(prediction))
        except IOError as e:
            print(e)
            print("Something went wrong while reading test file {}".format(test_file))
            sys.exit(0)
            
    print("Finished making predictions at {}".format(datetime.now()))

def main():
    '''Standard method in Python that does not need a docstring. Don't worry about it for now, we will get to know it
    more deeply in week 6.
    '''
    
    corpus_dir = 'files_for_development/20news-18828'
    test_dir = 'files_for_development/dev-set'
    keys_file = 'files_for_development/dev_keys.txt'

    nb_classifier = NaiveBayes()

    if corpus_dir:
        train_model(corpus_dir, nb_classifier)

    if test_dir:
        make_predictions("predictions.txt", test_dir, nb_classifier)

    if keys_file:
        accuracy_checker(keys_file, "predictions.txt")
        # system("{} accuracy_checker.py {} predictions.txt".format(my_python, keys_file))


if __name__ == '__main__':
    main()
# Out:
# Starting training at 2020-11-25 16:20:31.909833
# Training on label comp.sys.mac.hardware
# Training on label misc.forsale
# Training on label talk.politics.guns
# Training on label sci.space
# Training on label soc.religion.christian
# Training on label sci.med
# Training on label comp.sys.ibm.pc.hardware
# Training on label rec.sport.hockey
# Training on label comp.graphics
# Training on label talk.religion.misc
# Training on label talk.politics.mideast
# Training on label sci.crypt
# Training on label rec.motorcycles
# Training on label rec.sport.baseball
# Training on label comp.windows.x
# Training on label talk.politics.misc
# Training on label comp.os.ms-windows.misc
# Training on label rec.autos
# Training on label sci.electronics
# Training on label alt.atheism
# Starting to smooth and normalise at 2020-11-25 16:20:37.812858
# Finished training at 2020-11-25 16:20:45.533259
# Start making predictions at 2020-11-25 16:20:45.533453
# Finished making predictions at 2020-11-25 16:20:50.512668
# The overlap between the gold list and the student output is 85.1%

# %%
accuracy_checker('predictions.txt', 'files_for_development/dev_keys.txt')
# Out:
# The overlap between the gold list and the student output is 85.1%
